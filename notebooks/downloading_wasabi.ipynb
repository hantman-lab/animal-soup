# %% [markdown]
# ### Downloading from wasabi

# %%
from pathlib import Path
from tqdm import tqdm
import shutil
import os

# %%
vpath = Path("/home/clewis7/wasabi/hantmanlab/from_tier2/Jay/videos")

# %%
mpaths = sorted(vpath.glob("M*"))

# %%
post_processed = list()

# %%
for p in tqdm(mpaths):
    jp = list(p.joinpath("postprocessed").glob("*.mat"))
    if len(jp) > 0:
        post_processed += jp
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 150/150 [00:34<00:00,  4.31it/s]

# %%
len(post_processed)
# Out:
# 702

# %%
post_processed
# Out:
# [PosixPath('/home/clewis7/wasabi/hantmanlab/from_tier2/Jay/videos/M206hm4dBPN/postprocessed/M206_1stPastaCNO.mat'),
#  PosixPath('/home/clewis7/wasabi/hantmanlab/from_tier2/Jay/videos/M206hm4dBPN/postprocessed/M206_1stPelletCNO.mat'),
#  PosixPath('/home/clewis7/wasabi/hantmanlab/from_tier2/Jay/videos/M206hm4dBPN/postprocessed/M206_2ndPastaCNO.mat'),
#  PosixPath('/home/clewis7/wasabi/hantmanlab/from_tier2/Jay/videos/M206hm4dBPN/postprocessed/M206_All3TPelletCNO.mat'),
#  PosixPath('/home/clewis7/wasabi/hantmanlab/from_tier2/Jay/videos/M232Slc17a7_Gtacr2/postprocessed/M232_20170306.mat'),
#  PosixPath('/home/clewis7/wasabi/hantmanlab/from_tier2/Jay/videos/M232Slc17a7_Gtacr2/postprocessed/M232_20170307.mat'),
#  PosixPath('/home/clewis7/wasabi/hantmanlab/from_tier2/Jay/videos/M232Slc17a7_Gtacr2/postprocessed/M232_20170308.mat'),
#  PosixPath('/home/clewis7/wasabi/hantmanlab/from_tier2/Jay/videos/M232Slc17a7_Gtacr2/postprocessed/M232_20170310.mat'),
# ...

# %%
# downloading when videos are organized under session_id date
# local_parent_path = Path('/data/caitlin/training-vids')
# not_found = list()

# for mat_path in mat_paths:
#     parts = mat_path.parts
#     wasabi_dir = Path(*parts[:9]) # directory of animal in Wasabi
#     animal_id = parts[8] # animal_id to create in home dir
#     session_id = parts[-1].split('_')[1].split('.')[0] # date for videos
#     session_dir = wasabi_dir.joinpath(session_id) # session dir path in wasabi

#     # check if session_id folder exists in wasabi
#     if os.path.exists(session_dir): # session_id folder exists in animal_dir
#         avi_folders = sorted(session_dir.glob("*_v*"))
#         if len(avi_folders) > 0: # means that there are video folder found
#             # create animal dir in home
#             animal_dir = local_parent_path.joinpath(animal_id)
#             session_dir = animal_dir.joinpath(session_id)
#             os.makedirs(session_dir, exist_ok=True)
            
#             # add mat file and corresponding videos in session dir
#             shutil.copy(src=mat_path, dst=session_dir.joinpath(f"jaaba.mat"))
            
#             for vid_trial_dir in tqdm(avi_folders):
#                 try:
#                     vid_trial = vid_trial_dir.joinpath('movie_comb.avi')
#                     shutil.copy(src=vid_trial, dst=session_dir.joinpath(f"{vid_trial_dir.stem}.avi"))
#                 except NotADirectoryError:
#                     continue
#                 # os.rename(os.path.join(parent_path, animal_id, session_id, 'movie_comb.avi'), os.path.join(parent_path, animal_id, session_id, folder.parts[-1].split('_')[-1]))
#         else: # no avi folder were found, need to check near_line potentially
#             not_found.append(path)
#             continue
#     else: # weird org likely, skipping for now
#         not_found.append(path) 
#         continue

# %%
#not_found
# Out:
# []

# %%
mat_paths = [
#Path('/home/clewis7/wasabi/hantmanlab/from_tier2/Jay/videos/M254VGATXChR2_TH/postprocessed/M254_20180301_4thCxRecording.mat'), 'ctr'
Path('/home/clewis7/wasabi/hantmanlab/from_tier2/Jay/videos/M254VGATXChR2_TH/postprocessed/M254_20180302_5thCxRecording.mat'),
Path('/home/clewis7/wasabi/hantmanlab/from_tier2/Jay/videos/M254VGATXChR2_TH/postprocessed/M254_20180305_6thCxRecording.mat'),
Path('/home/clewis7/wasabi/hantmanlab/from_tier2/Jay/videos/M254VGATXChR2_TH/postprocessed/M254_20180306_7thCxRecording.mat'),
Path('/home/clewis7/wasabi/hantmanlab/from_tier2/Jay/videos/M254VGATXChR2_TH/postprocessed/M254_20180307_8thCxRecording.mat'),
Path('/home/clewis7/wasabi/hantmanlab/from_tier2/Jay/videos/M254VGATXChR2_TH/postprocessed/M254_20180308_9thCxRecording.mat'),
Path('/home/clewis7/wasabi/hantmanlab/from_tier2/Jay/videos/M254VGATXChR2_TH/postprocessed/M254_20180309_10thCxRecording.mat'),
Path('/home/clewis7/wasabi/hantmanlab/from_tier2/Jay/videos/M254VGATXChR2_TH/postprocessed/M254_20180312_11thCxRecording.mat'),
Path('/home/clewis7/wasabi/hantmanlab/from_tier2/Jay/videos/M254VGATXChR2_TH/postprocessed/M254_20180313_12thCxRecording.mat'),
Path('/home/clewis7/wasabi/hantmanlab/from_tier2/Jay/videos/M254VGATXChR2_TH/postprocessed/M254_20180314_13thCxRecording.mat'),
Path('/home/clewis7/wasabi/hantmanlab/from_tier2/Jay/videos/M254VGATXChR2_TH/postprocessed/M254_20180315_14thCxRecording.mat'),
Path('/home/clewis7/wasabi/hantmanlab/from_tier2/Jay/videos/M254VGATXChR2_TH/postprocessed/M254_20180316_15thCxRecording.mat'),
Path('/home/clewis7/wasabi/hantmanlab/from_tier2/Jay/videos/M254VGATXChR2_TH/postprocessed/M254_20180319_16thCxRecording.mat'),
Path('/home/clewis7/wasabi/hantmanlab/from_tier2/Jay/videos/M254VGATXChR2_TH/postprocessed/M254_20180320_17thCxRecording.mat'),
Path('/home/clewis7/wasabi/hantmanlab/from_tier2/Jay/videos/M254VGATXChR2_TH/postprocessed/M254_20180321_18thCxRecording.mat'),
Path('/home/clewis7/wasabi/hantmanlab/from_tier2/Jay/videos/M254VGATXChR2_TH/postprocessed/M254_20180322_19thCxRecording.mat'),
Path('/home/clewis7/wasabi/hantmanlab/from_tier2/Jay/videos/M254VGATXChR2_TH/postprocessed/M254_20180323_20thCxRecording.mat'),
Path('/home/clewis7/wasabi/hantmanlab/from_tier2/Jay/videos/M254VGATXChR2_TH/postprocessed/M254_20180326_21thCxRecording.mat'),
Path('/home/clewis7/wasabi/hantmanlab/from_tier2/Jay/videos/M254VGATXChR2_TH/postprocessed/M254_20180327_22thCxRecording.mat'),
Path('/home/clewis7/wasabi/hantmanlab/from_tier2/Jay/videos/M254VGATXChR2_TH/postprocessed/M254_20180328_23thCxRecording.mat'),
        ]

# %%
local_parent_path = Path('/data/caitlin/training-vids')
not_found = list()

for mat_path in tqdm(mat_paths):
    parts = mat_path.parts
    wasabi_dir = Path(*parts[:9]) # directory of animal in Wasabi
    animal_id = parts[8] # animal_id to create in home dir
    session_id = parts[-1].split('_')[1].split('.')[0] # date for videos
    session_dir = wasabi_dir.joinpath(f'{session_id}', 'CTR') # session dir path in wasabi
    
    print(session_dir, session_id)
    
    if os.path.exists(session_dir): 
        # control_folders = sorted(session_dir.glob('A*'))
        # for c_folder in control_folders:
        #     avi_folders = sorted(c_folder.glob("*_v*"))
        avi_folders = sorted(session_dir.glob("*_v*"))
        #print(avi_folders)
        if len(avi_folders) > 0: # means that there are video folder found
        # create animal dir in home
            animal_dir = local_parent_path.joinpath(animal_id)
            session_dir = animal_dir.joinpath(session_id)
            os.makedirs(session_dir, exist_ok=True)

            # add mat file and corresponding videos in session dir
            shutil.copy(src=mat_path, dst=session_dir.joinpath(f"jaaba.mat"))

            for vid_trial_dir in tqdm(avi_folders):
                try:
                    vid_trial = vid_trial_dir.joinpath('movie_comb.avi')
                    shutil.copy(src=vid_trial, dst=session_dir.joinpath(f"{vid_trial_dir.stem}.avi"))
                except NotADirectoryError:
                    continue
        else:
            raise ValueError("no avi folders found")
    else:
        raise ValueError("session dir does not exist")
# Out:
#   0%|                                                                                        | 0/19 [00:00<?, ?it/s]
# /home/clewis7/wasabi/hantmanlab/from_tier2/Jay/videos/M254VGATXChR2_TH/20180302/CTR 20180302
# ...
#   5%|████                                                                         | 1/19 [04:40<1:24:10, 280.56s/it]
# /home/clewis7/wasabi/hantmanlab/from_tier2/Jay/videos/M254VGATXChR2_TH/20180305/CTR 20180305
# ...
#  11%|████████                                                                     | 2/19 [09:25<1:20:09, 282.91s/it]
# /home/clewis7/wasabi/hantmanlab/from_tier2/Jay/videos/M254VGATXChR2_TH/20180306/CTR 20180306
# ...
#  16%|████████████▏                                                                | 3/19 [15:50<1:27:54, 329.65s/it]
# /home/clewis7/wasabi/hantmanlab/from_tier2/Jay/videos/M254VGATXChR2_TH/20180307/CTR 20180307
# ...
#  13%|██████████▍                                                                   | 16/120 [00:48<05:16,  3.05s/it]
# ...
# ...
